# %% [markdown]
# <a href="https://colab.research.google.com/github/PatchareepornT/Basicprg_DataViz65/blob/main/ProjectBPDV65.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
unit1 = pd.read_csv('/content/drive/MyDrive/ProjectBPDV65/opendata_unittype.csv')
unit1.head()
# Out:
#    row_number               unittype_id     project_id          name_th  \
# 0        2493             unittype_9387   project_3212     Silver Rhine
# 1       38654  5f631dc55bdc5300198eb3bf  project_15528        ลลิลพฤกษ์
# 2       24493            unittype_14696   project_5931           กุสุมา
# 3       12834            unittype_34632  project_14929  ทาวน์โฮมสองชั้น
# 4       17863            unittype_20458   project_8017        1 Bedroom
#
#    propertytype_id propertytype_name_en propertytype_name_th  \
# 0                1       Detached House                 บ้าน
# 1                1       Detached House                 บ้าน
# 2                1       Detached House                 บ้าน
# 3                3             Townhome             ทาวน์โฮม
# 4                2                Condo                คอนโด
#
#    area_total_min_wa  area_usable_min  price_min  ...  count_room_kitchen  \
# 0               60.0           275.00  8990000.0  ...                 1.0
# ...

# %%
unit1.isnull().any()
# Out:
# row_number              False
# unittype_id             False
# project_id              False
# name_th                 False
# propertytype_id         False
# propertytype_name_en    False
# propertytype_name_th    False
# area_total_min_wa        True
# area_usable_min          True
# price_min                True
# count_airconditioner     True
# count_elevator           True
# count_floor_internal     True
# count_parking            True
# count_room_bath          True
# count_room_bed           True
# count_room_dinning       True
# count_room_guest         True
# count_room_kitchen       True
# count_room_living        True
# count_room_maid          True
# count_room_storage       True
# count_room_utility       True
# date_created            False
# date_updated            False
# source                  False
# url_unittype            False
# day                     False
# dtype: bool

# %%
unit2 = unit1[['unittype_id','project_id','name_th','propertytype_name_th','area_usable_min','price_min']]
unit2
# Out:
#                     unittype_id     project_id              name_th  \
# 0                 unittype_9387   project_3212         Silver Rhine
# 1      5f631dc55bdc5300198eb3bf  project_15528            ลลิลพฤกษ์
# 2                unittype_14696   project_5931               กุสุมา
# 3                unittype_34632  project_14929      ทาวน์โฮมสองชั้น
# 4                unittype_20458   project_8017            1 Bedroom
# ...                         ...            ...                  ...
# 41679            unittype_32240  project_13504               Studio
# 41680            unittype_16596   project_6570      ทาวน์โฮมสามชั้น
# 41681            unittype_27780  project_11187  อาคารพาณิชย์สองชั้น
# 41682             unittype_9574   project_2338      ทาวน์โฮมสองชั้น
# 41683  5f5b3c49a1fefc0012ef3040  project_17337          Chester III
#
#       propertytype_name_th  area_usable_min  price_min
# 0                     บ้าน           275.00  8990000.0
# ...

# %%
unit2.isnull().any()
# Out:
# unittype_id             False
# project_id              False
# name_th                 False
# propertytype_name_th    False
# area_usable_min          True
# price_min                True
# dtype: bool

# %%
unit= unit2.dropna()

# %%
unit.isnull().any()
# Out:
# unittype_id             False
# project_id              False
# name_th                 False
# propertytype_name_th    False
# area_usable_min         False
# price_min               False
# dtype: bool

# %%
project1 = pd.read_csv('/content/drive/MyDrive/ProjectBPDV65/opendata_project.csv')
project1.head()
# Out:
# /usr/local/lib/python3.7/dist-packages/IPython/core/interactiveshell.py:3326: DtypeWarning: Columns (27) have mixed types.Specify dtype option on import or set low_memory=False.
#   exec(code_obj, self.user_global_ns, self.user_ns)
#    row_number                project_id               name_en  \
# 0      7559.0             project_10253  The Villa Rachawadee
# 1       436.0             project_15897   Rajchaprarop Garden
# 2     19301.0             project_10774             Baan Nayu
# 3      8877.0  5ea1685438be3400128e3698        Utopia Central
# 4     12216.0              project_1161            Rose Sarin
#
#                name_th propertytype_id propertytype_name_en  \
# 0  เดอะ วิลล่า ราชาวดี               1       Detached House
# 1    ราชปรารภ การ์เด้น               2                Condo
# 2          บ้านน่าอยู่               4           Commercial
# 3    ยูโทเปีย เซ็นทรัล               2                Condo
# 4  โรสรินทร์ (ท่ารั้ว)               3             Townhome
#
# ...

# %%
project1.isnull().any()
# Out:
# row_number                 True
# project_id                False
# name_en                   False
# name_th                   False
# propertytype_id           False
# propertytype_name_en      False
# propertytype_name_th      False
# price_min                  True
# developer_id              False
# developer_name_en          True
# developer_name_th          True
# latitude                  False
# longitude                  True
# neighborhood_id            True
# neighborhood_name_en       True
# neighborhood_name_th       True
# subdistrict_id             True
# subdistrict_name_en        True
# subdistrict_name_th        True
# district_id                True
# district_name_en           True
# district_name_th           True
# province_id                True
# province_name_en           True
# province_name_th           True
# zipcode                    True
# count_elevator             True
# count_elevator_service     True
# count_floor                True
# ...

# %%
project2 = project1[['project_id','name_th','propertytype_name_th','price_min','longitude','longitude','neighborhood_name_th','subdistrict_name_th','district_name_th','province_name_th']]
project2
# Out:
#                      project_id                         name_th  \
# 0                 project_10253             เดอะ วิลล่า ราชาวดี
# 1                 project_15897               ราชปรารภ การ์เด้น
# 2                 project_10774                     บ้านน่าอยู่
# 3      5ea1685438be3400128e3698               ยูโทเปีย เซ็นทรัล
# 4                  project_1161             โรสรินทร์ (ท่ารั้ว)
# ...                         ...                             ...
# 22962             project_11378                     สุขปิติ วิว
# 22963               project_958                   บ้านคำหยาดฟ้า
# 22964             project_10169                       บ่อวินนคร
# 22965             project_13557      ออล สวีท ภูเก็ตซิตี้-พันวา
# 22966             project_15322  บ้านรติรัตน์ บ้านกล้วย-ไทรน้อย
#
#       propertytype_name_th  price_min   longitude   longitude  \
# 0                     บ้าน  4690000.0  100.903702  100.903702
# 1                    คอนโด  1550000.0  100.549295  100.549295
# ...

# %%
project2.isnull().any()
# Out:
# project_id              False
# name_th                 False
# propertytype_name_th    False
# price_min                True
# longitude                True
# longitude                True
# neighborhood_name_th     True
# subdistrict_name_th      True
# district_name_th         True
# province_name_th         True
# dtype: bool

# %%
project= project2.dropna()

# %%
project.isnull().any()
# Out:
# project_id              False
# name_th                 False
# propertytype_name_th    False
# price_min               False
# longitude               False
# longitude               False
# neighborhood_name_th    False
# subdistrict_name_th     False
# district_name_th        False
# province_name_th        False
# dtype: bool

# %%
train_station = pd.read_csv('/content/drive/MyDrive/ProjectBPDV65/opendata_train_station.csv')
train_station.head()
# Out:
#    row_number  gid  line_no  railway            line_typt          line_type  \
# 0          45  256        9  รถไฟฟ้า         เอ็มอาร์ทีเอ                MRT
# 1          29  216        8  รถไฟฟ้า           เอ็มอาร์ที                MRT
# 2         109  232        8  รถไฟฟ้า           เอ็มอาร์ที                MRT
# 3         176  219        8  รถไฟฟ้า           เอ็มอาร์ที                MRT
# 4          55  152        5  รถไฟฟ้า  แอร์พอร์ต-เรล-ลิงค์  Airport-Rail-Link
#
#      status              line_th            line_en    station_th  \
# 0     อนาคต          สายสีเหลือง        Yellow Line       ศรีเทพา
# 1     อนาคต             สายสีส้ม        Orange Line     น้อมเกล้า
# 2     อนาคต             สายสีส้ม        Orange Line        ดินแดง
# 3     อนาคต             สายสีส้ม        Orange Line  เคหะรามคำแหง
# 4  ปัจจุบัน  แอร์พอร์ต เรล ลิงค์  Airport Rail Link       หัวหมาก
#
#           station_en   latitude   longitude      prov_namt     prov_name  \
# ...

# %%
train_station.isnull().any()
# Out:
# row_number    False
# gid           False
# line_no       False
# railway       False
# line_typt     False
# line_type     False
# status        False
# line_th       False
# line_en       False
# station_th    False
# station_en    False
# latitude      False
# longitude     False
# prov_namt     False
# prov_name     False
# amp_namt      False
# amp_name      False
# tam_namt      False
# tam_name      False
# day           False
# dtype: bool

# %%
train_line = pd.read_csv('/content/drive/MyDrive/ProjectBPDV65/opendata_train_line.csv')
train_line.head()
# Out:
#    row_number            name                       area    status  \
# 0          22     สายสีน้ำตาล               แคราย-ลำสาลี     อนาคต
# 1          16  สายสีเขียวอ่อน         ตลิ่งชัน - บางหว้า     อนาคต
# 2          18    สายสีแดงเข้ม          มหาชัย - รางโพธิ์     อนาคต
# 3          19    สายสีน้ำเงิน  บางซื่อ - เตาปูน - ท่าพระ  ปัจจุบัน
# 4          41    สายสีแดงอ่อน           มักกะสัน-หัวหมาก     อนาคต
#
#                                             geometry         day
# 0  LINESTRING (100.5155029670176 13.8599801163895...  2022-11-01
# 1  LINESTRING (100.4402600000001 13.7892089999999...  2022-11-01
# 2  LINESTRING (100.2609130546652 13.5609441473892...  2022-11-01
# 3  LINESTRING (100.4943425960887 13.7844907442280...  2022-11-01
# 4  LINESTRING (100.643561 13.73794300000001, 100....  2022-11-01

# %%
train_line.isnull().any()
# Out:
# row_number    False
# name          False
# area          False
# status        False
# geometry      False
# day           False
# dtype: bool

# %%
eating_score = pd.read_csv('/content/drive/MyDrive/ProjectBPDV65/opendata_eating_score.csv')
eating_score.head()
# Out:
#    row_number  subdistrict_id subdistrict_name_en subdistrict_name_th  \
# 0          95            3835      SALA THAMMASOP        ศาลาธรรมสพน์
# 1          17            3602       BANG KHAYAENG            บางขะแยง
# 2          11            3793    SAI KONG DIN TAI       ทรายกองดินใต้
# 3         203            3652      CHIANG RAK YAI        เชียงรากใหญ่
# 4         185            3442           BAN LAENG             บ้านแลง
#
#    district_id     district_name_en district_name_th  province_id  \
# 0         3833       THAWI WATTHANA         ทวีวัฒนา         3781
# 1         3600  MUEANG PATHUM THANI    เมืองปทุมธานี         3599
# 2         3791        KHLONG SAM WA        คลองสามวา         3781
# 3         3647             SAM KHOK           สามโคก         3599
# 4         3432        MUEANG RAYONG       เมืองระยอง         3431
#
#   province_name_en province_name_th  eating_daytime  eating_daytime_price  \
# ...

# %%
eating_score.isnull().any()
# Out:
# row_number                  False
# subdistrict_id              False
# subdistrict_name_en         False
# subdistrict_name_th         False
# district_id                 False
# district_name_en            False
# district_name_th            False
# province_id                 False
# province_name_en            False
# province_name_th            False
# eating_daytime              False
# eating_daytime_price        False
# eating_daytime_quality      False
# eating_daytime_variety      False
# eating_nighttime            False
# eating_nighttime_price      False
# eating_nighttime_quality    False
# eating_nighttime_variety    False
# source                      False
# day                         False
# dtype: bool

# %%
living_score= pd.read_csv('/content/drive/MyDrive/ProjectBPDV65/opendata_living_score.csv')
living_score.head()
# Out:
#    row_number  subdistrict_id subdistrict_name_en subdistrict_name_th  \
# 0         184            3809            BANG KHO              บางค้อ
# 1         320            3692       NONG PAK LONG          หนองปากโลง
# 2          47            3828    KHLONG CHAK PHRA          คลองชักพระ
# 3          84            3951         LAT KRABANG           ลาดกระบัง
# 4         118            3872           BANG PHAI              บางไผ่
#
#    district_id      district_name_en district_name_th  province_id  \
# 0         3806            CHOM THONG           จอมทอง         3781
# 1         3668  MUEANG NAKHON PATHOM      เมืองนครปฐม         3667
# 2         3826           TALING CHAN         ตลิ่งชัน         3781
# 3         3950           LAT KRABANG        ลาดกระบัง         3781
# 4         3869             BANG KHAE            บางแค         3781
#
#   province_name_en province_name_th  ...  access_train  access_total  \
# ...

# %%
living_score.isnull().any()
# Out:
# row_number              False
# subdistrict_id          False
# subdistrict_name_en     False
# subdistrict_name_th     False
# district_id             False
# district_name_en        False
# district_name_th        False
# province_id             False
# province_name_en        False
# province_name_th        False
# walk_leisure            False
# walk_public_service     False
# walk_school             False
# walk_shopping           False
# walk_work               False
# walk_total              False
# access_boat             False
# access_bus              False
# access_train            False
# access_total            False
# drive_leisure           False
# drive_public_service    False
# drive_school            False
# drive_shopping          False
# drive_work              False
# drive_total             False
# source                  False
# day                     False
# dtype: bool

# %%
volume_listing_rent= pd.read_csv('/content/drive/MyDrive/ProjectBPDV65/opendata_volume_listing_rent.csv')
volume_listing_rent.head()
# Out:
#    row_number  transction_year  transction_month project_province_name_th  \
# 0          17             2021                10                  นนทบุรี
# 1        1224             2019                10            กรุงเทพมหานคร
# 2        1085             2021                 7            กรุงเทพมหานคร
# 3         187             2019                 1            กรุงเทพมหานคร
# 4        1582             2022                 1            กรุงเทพมหานคร
#
#   project_province_name_en project_district_name_th project_district_name_en  \
# 0               Nonthaburi             เมืองนนทบุรี        MUEANG NONTHABURI
# 1                  Bangkok                 ดอนเมือง               DON MUEANG
# 2                  Bangkok                    วัฒนา                  VADHANA
# 3                  Bangkok                  คลองเตย              KHLONG TOEI
# 4                  Bangkok               บางกอกน้อย              BANGKOK NOI
#
# ...

# %%
volume_listing_rent.isnull().any()
# Out:
# row_number                      False
# transction_year                 False
# transction_month                False
# project_province_name_th        False
# project_province_name_en        False
# project_district_name_th        False
# project_district_name_en        False
# project_propertytype_name_th    False
# project_propertytype_name_en    False
# volume_of_rental                False
# day                             False
# dtype: bool

# %%
median_price_rent= pd.read_csv('/content/drive/MyDrive/ProjectBPDV65/opendata_median_price_rent.csv')
median_price_rent.head()
# Out:
#    row_number  transction_year  transction_month project_province_name_th  \
# 0        1427             2020                 3            กรุงเทพมหานคร
# 1        1992             2021                 7            กรุงเทพมหานคร
# 2        1971             2021                 7                  นนทบุรี
# 3         374             2022                 1            กรุงเทพมหานคร
# 4        1739             2019                 4            กรุงเทพมหานคร
#
#   project_province_name_en project_district_name_th project_district_name_en  \
# 0                  Bangkok               บางกอกน้อย              BANGKOK NOI
# 1                  Bangkok                ภาษีเจริญ            PHASI CHAROEN
# 2               Nonthaburi                 ปากเกร็ด                 PAK KRET
# 3                  Bangkok              ราษฎร์บูรณะ               RAT BURANA
# 4                  Bangkok                  สวนหลวง               SUAN LUANG
#
# ...

# %%
median_price_rent.isnull().any()
# Out:
# row_number                      False
# transction_year                 False
# transction_month                False
# project_province_name_th        False
# project_province_name_en        False
# project_district_name_th        False
# project_district_name_en        False
# project_propertytype_name_th    False
# project_propertytype_name_en    False
# total_listing                   False
# median_rent_price_sqm           False
# day                             False
# dtype: bool
